# %%
import pandas
import pandas as pd

# %%
ventas = pandas.read_json("ventas.json", orient="split", encoding="utf-8")
 
datos = pd.DataFrame(
    ventas,     
    columns = ['id', 'producto', 'cliente', 'dni', 'fnacimientocliente', 'precio', 'img', 'created_at', 'updated_at'])
 
datos
# Out:
#     id             producto                          cliente       dni  \
# 0    1   Torta de Chocolate  Julieta Verónica Vergara Aquino  42514784
# 1    2             Limonada  Julieta Verónica Vergara Aquino  42514784
# 2    3    Gelatina de Fresa     Luis Roberto Torres Gonzales  46238625
# 3    4             Limonada     Luis Roberto Torres Gonzales  46238625
# 4    5      Arroz con Leche   Maria Rafaela Torres Maldonado  72632605
# 5    6       Cafe Americano   Maria Rafaela Torres Maldonado  72632605
# 6    7       Pie de Manzana          Luis Pedro Nuñez Balboa  76312605
# 7    8        Jugo de Fresa          Luis Pedro Nuñez Balboa  76312605
# 8    9  Suspiro a la Limeña      Karina Penélope Rojas Prado  76322423
# 9   10       Jugo de Papaya      Karina Penélope Rojas Prado  76322423
# 10  11    Gelatina de Fresa     Marcos Jorge Quiñones Rosado  72612605
# 11  12                   Té     Marcos Jorge Quiñones Rosado  72612605
# 12  13      Arroz con Leche       Carlos Daniel Posada Rojas  76814604
# 13  14             Limonada       Carlos Daniel Posada Rojas  76814604
# 14  15   Torta de Chocolate    Daniela Rosa Benavides Arbulú  76589475
# 15  16       Cafe Americano    Daniela Rosa Benavides Arbulú  76589475
# 16  17      Arroz con Leche         Juan Carlos Ormeño Saenz  46528604
# 17  18                   Té         Juan Carlos Ormeño Saenz  46528604
# 18  19    Gelatina de Fresa      Perina Janeth Dias Portales  76898659
# 19  20        Jugo de Fresa      Perina Janeth Dias Portales  76898659
#
#    fnacimientocliente  precio                              img  \
# 0          19-02-1984     5.5          af_Nnz0Jyn_4QhIPnb.jpeg
# 1          19-02-1984     4.5  af_Nnz0Jyn_4QhIPnb_SsbsVPi.jpeg
# 2          23-04-1985     4.5               images_UgZuKKp.png
# 3          23-04-1985     4.5               images_hIkthkl.png
# 4          02-03-1980     3.6                  af_0ZtBRQD.jpeg
# 5          02-03-1980     2.8                  af_jwk4STE.jpeg
# 6          15-05-2010     4.5                  ann_yuAEAeS.png
# 7          15-05-2010     3.5                  ann_vR37j7W.png
# 8          12-08-2003     3.8                  amn_WlKjRre.png
# 9          12-08-2003     3.0                  amn_Erebcoj.png
# 10         17-04-1950     4.5       images_FGx00CU_DY03ZfZ.png
# 11         17-04-1950     2.5       images_FGx00CU_kFFrzoC.png
# 12         16-03-2009     3.6          ann_rSaVhUX_udfQ2mw.png
# 13         16-03-2009     4.5          ann_rSaVhUX_iB76xzg.png
# 14         25-10-1965     5.5          af_azwua5h_uircadO.jpeg
# 15         25-10-1965     2.8          af_azwua5h_EbYp4dD.jpeg
# 16         18-07-1985     3.6       images_BuUI4k0_oUpcSen.png
# 17         18-07-1985     2.5       images_BuUI4k0_55y16j5.png
# 18         25-11-2007     4.5          amn_JXUIM0g_Zgip831.png
# 17 2019-09-16 21:06:06.479639 2019-09-16 23:06:06.479639
# 18 2019-09-16 22:06:56.924524 2019-09-16 23:06:56.924524
# 19 2019-09-16 22:07:24.298089 2019-09-16 23:07:24.298089

# %%
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 20,11

# %%
resultado.plot(x="producto", y="created_at")

# %%
# Formateo para extraer solo la hora de la venta
datos['created_at'] = pd.to_datetime(datos['created_at'])
ff = datos['created_at'].dt.strftime('%H:%M:%S %p') # Formato 00:00:00 AM/PM 
datos['created_at'] = ff  

# Selecciono las ventas del rango horario de la noche
horai = '18:00:00'
horaf = '23:00:00'

filtrar = (ff >= horai) & (ff <= horaf)
resultado = datos.loc[filtrar]

# Cambio el nombre de las columnas para mejorar su aspecto 
resultado.columns = ['ID', 'Producto', 'Cliente', 'DNI', 'Fecha de Nacimiento', 'Precio', 'Imagen', 'Hora', 'Actualizado'] 

resultado
# Out:
#     ID            Producto                        Cliente       DNI  \
# 14  15  Torta de Chocolate  Daniela Rosa Benavides Arbulú  76589475
# 15  16      Cafe Americano  Daniela Rosa Benavides Arbulú  76589475
# 16  17     Arroz con Leche       Juan Carlos Ormeño Saenz  46528604
# 17  18                  Té       Juan Carlos Ormeño Saenz  46528604
# 18  19   Gelatina de Fresa    Perina Janeth Dias Portales  76898659
# 19  20       Jugo de Fresa    Perina Janeth Dias Portales  76898659
#
#    Fecha de Nacimiento  Precio                      Imagen         Hora  \
# 14          25-10-1965     5.5     af_azwua5h_uircadO.jpeg  18:00:27 PM
# 15          25-10-1965     2.8     af_azwua5h_EbYp4dD.jpeg  19:00:49 PM
# 16          18-07-1985     3.6  images_BuUI4k0_oUpcSen.png  20:05:45 PM
# 17          18-07-1985     2.5  images_BuUI4k0_55y16j5.png  21:06:06 PM
# 18          25-11-2007     4.5     amn_JXUIM0g_Zgip831.png  22:06:56 PM
# 19          25-11-2007     3.5     amn_JXUIM0g_zUDqcFw.png  22:07:24 PM
#
#                   Actualizado
# 14 2019-09-16 23:00:27.046224
# 15 2019-09-16 23:00:49.938533
# 16 2019-09-16 23:05:45.279426
# 17 2019-09-16 23:06:06.479639
# 18 2019-09-16 23:06:56.924524
# 19 2019-09-16 23:07:24.298089

# %%
import matplotlib.pyplot as plot
import numpy as np

# Tamaño del gráfico 
plot.rcParams["figure.figsize"] = 20,11

# Defino los campos del gráfico 
horas = resultado['Hora']
posisicion_y = np.arange(len(horas))
productos = resultado['Producto']

# Formateo los elementos del gráfico 
plot.plot(posisicion_y, productos, alpha=0.5)
plot.xticks(posisicion_y, horas)
plot.xticks(fontsize=16)
plot.yticks(fontsize=16)

# Defino el título y las etiquetas (labels) del gráfico 
plot.title('Día: 16-09-2019', fontsize=24, pad=25)
plot.xlabel('Hora', fontsize=20, labelpad=25)
plot.ylabel('Producto', fontsize=20, labelpad=25)

# Imprimo el gráfico 
plot.scatter(posisicion_y, productos) # Añado puntos azules al gráfico
plot.show()
