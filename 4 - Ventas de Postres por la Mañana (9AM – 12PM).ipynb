# %%
import pandas
import pandas as pd

# %%
ventas = pandas.read_json("ventas.json", orient="split", encoding="utf-8")
 
datos = pd.DataFrame(
    ventas,     
    columns = ['id', 'producto', 'categoria', 'cliente', 'dni', 'fnacimientocliente', 'precio', 'img', 'created_at', 'updated_at'])
 
datos
# Out:
#     id             producto categoria                          cliente  \
# 0    1   Torta de Chocolate    postre  Julieta Verónica Vergara Aquino
# 1    2             Limonada    bebida  Julieta Verónica Vergara Aquino
# 2    3    Gelatina de Fresa    postre     Luis Roberto Torres Gonzales
# 3    4             Limonada    bebida     Luis Roberto Torres Gonzales
# 4    5      Arroz con Leche    postre   Maria Rafaela Torres Maldonado
# 5    6       Cafe Americano    bebida   Maria Rafaela Torres Maldonado
# 6    7       Pie de Manzana    postre          Luis Pedro Nuñez Balboa
# 7    8        Jugo de Fresa    bebida          Luis Pedro Nuñez Balboa
# 8    9  Suspiro a la Limeña    postre      Karina Penélope Rojas Prado
# 9   10       Jugo de Papaya    bebida      Karina Penélope Rojas Prado
# 10  11    Gelatina de Fresa    postre     Marcos Jorge Quiñones Rosado
# 11  12                   Té    bebida     Marcos Jorge Quiñones Rosado
# 12  13      Arroz con Leche    postre       Carlos Daniel Posada Rojas
# 13  14             Limonada    bebida       Carlos Daniel Posada Rojas
# 14  15   Torta de Chocolate    postre    Daniela Rosa Benavides Arbulú
# 15  16       Cafe Americano    bebida    Daniela Rosa Benavides Arbulú
# 16  17      Arroz con Leche    postre         Juan Carlos Ormeño Saenz
# 17  18                   Té    bebida         Juan Carlos Ormeño Saenz
# 18  19    Gelatina de Fresa    postre      Perina Janeth Dias Portales
# 19  20        Jugo de Fresa    bebida      Perina Janeth Dias Portales
#
#          dni fnacimientocliente  precio                              img  \
# 0   42514784         19-02-1984     5.5          af_Nnz0Jyn_4QhIPnb.jpeg
# 1   42514784         19-02-1984     4.5  af_Nnz0Jyn_4QhIPnb_SsbsVPi.jpeg
# 2   46238625         23-04-1985     4.5               images_UgZuKKp.png
# 3   46238625         23-04-1985     4.5               images_hIkthkl.png
# 4   72632605         02-03-1980     3.6                  af_0ZtBRQD.jpeg
# 5   72632605         02-03-1980     2.8                  af_jwk4STE.jpeg
# 6   76312605         15-05-2010     4.5                  ann_yuAEAeS.png
# 7   76312605         15-05-2010     3.5                  ann_vR37j7W.png
# 8   76322423         12-08-2003     3.8                  amn_WlKjRre.png
# 9   76322423         12-08-2003     3.0                  amn_Erebcoj.png
# 10  72612605         17-04-1950     4.5       images_FGx00CU_DY03ZfZ.png
# 11  72612605         17-04-1950     2.5       images_FGx00CU_kFFrzoC.png
# 12  76814604         16-03-2009     3.6          ann_rSaVhUX_udfQ2mw.png
# 13  76814604         16-03-2009     4.5          ann_rSaVhUX_iB76xzg.png
# 14  76589475         25-10-1965     5.5          af_azwua5h_uircadO.jpeg
# 15  76589475         25-10-1965     2.8          af_azwua5h_EbYp4dD.jpeg
# 16  46528604         18-07-1985     3.6       images_BuUI4k0_oUpcSen.png
# 17  46528604         18-07-1985     2.5       images_BuUI4k0_55y16j5.png
# 18  76898659         25-11-2007     4.5          amn_JXUIM0g_Zgip831.png
# 19  76898659         25-11-2007     3.5          amn_JXUIM0g_zUDqcFw.png
#
#                    created_at                 updated_at
# 0  2019-09-16 09:22:12.314973 2019-09-16 22:22:12.314973
# 1  2019-09-16 09:35:35.676923 2019-09-16 22:35:35.676923
# 2  2019-09-16 10:37:45.498348 2019-09-16 22:37:45.498348
# 3  2019-09-16 10:44:53.271815 2019-09-16 22:44:53.271815
# 4  2019-09-16 11:47:48.986866 2019-09-16 22:47:48.986866
# 5  2019-09-16 11:59:03.943153 2019-09-16 22:50:54.333467
# 6  2019-09-16 12:52:03.898446 2019-09-16 22:52:03.898446
# 7  2019-09-16 13:52:47.198922 2019-09-16 22:52:47.198922
# 8  2019-09-16 13:54:36.598180 2019-09-16 22:54:36.598180
# 9  2019-09-16 14:55:06.337881 2019-09-16 22:55:06.337881
# 10 2019-09-16 15:56:27.961549 2019-09-16 22:56:27.961549
# 11 2019-09-16 15:58:14.925667 2019-09-16 22:58:14.925667
# 12 2019-09-16 16:59:17.676256 2019-09-16 22:59:17.676256
# 13 2019-09-16 17:59:41.447616 2019-09-16 22:59:41.448616
# 14 2019-09-16 18:00:27.046224 2019-09-16 23:00:27.046224
# 15 2019-09-16 19:00:49.938533 2019-09-16 23:00:49.938533
# 16 2019-09-16 20:05:45.279426 2019-09-16 23:05:45.279426
# 17 2019-09-16 21:06:06.479639 2019-09-16 23:06:06.479639
# 18 2019-09-16 22:06:56.924524 2019-09-16 23:06:56.924524
# 19 2019-09-16 22:07:24.298089 2019-09-16 23:07:24.298089

# %%
datos['created_at'] = pd.to_datetime(datos['created_at'])

# %%
hi = '2019-09-16 09:00:00.000000'
hf = '2019-09-16 12:00:00.000000'
categoria = 'postre'

# %%
datos['categoria'] = datos[['categoria']]

# %%
filtrar = (datos['created_at'] >= hi) & (datos['created_at'] <= hf) & (datos['categoria']== categoria)

# %%
resultado = datos.loc[filtrar]
resultado
# Out:
#    id            producto categoria                          cliente  \
# 0   1  Torta de Chocolate    postre  Julieta Verónica Vergara Aquino
# 2   3   Gelatina de Fresa    postre     Luis Roberto Torres Gonzales
# 4   5     Arroz con Leche    postre   Maria Rafaela Torres Maldonado
#
#         dni fnacimientocliente  precio                      img  \
# 0  42514784         19-02-1984     5.5  af_Nnz0Jyn_4QhIPnb.jpeg
# 2  46238625         23-04-1985     4.5       images_UgZuKKp.png
# 4  72632605         02-03-1980     3.6          af_0ZtBRQD.jpeg
#
#                   created_at                 updated_at
# 0 2019-09-16 09:22:12.314973 2019-09-16 22:22:12.314973
# 2 2019-09-16 10:37:45.498348 2019-09-16 22:37:45.498348
# 4 2019-09-16 11:47:48.986866 2019-09-16 22:47:48.986866

# %%
import matplotlib.pyplot as plot 
plot.rcParams["figure.figsize"] = 20,11

# %%
resultado.plot(x="producto", y="created_at")

# %%
# Formateo para extraer solo la hora de la venta
datos['created_at'] = pd.to_datetime(datos['created_at'])
ff = datos['created_at'].dt.strftime('%H:%M:%S %p') # Formato 00:00:00 AM/PM 
datos['created_at'] = ff  

# Selecciono las ventas del rango horario de la mañana
horai = '09:00:00'
horaf = '12:00:00'

# Defino la categoría que usaré 
categoria = 'postre' 

filtrar = (ff >= horai) & (ff <= horaf) & (datos['categoria']== categoria)
resultado = datos.loc[filtrar]

# Cambio el nombre de las columnas para mejorar su aspecto 
resultado.columns = ['ID', 'Producto', 'Categoría', 'Cliente', 'DNI', 'Fecha de Nacimiento', 'Precio', 'Imagen', 'Hora', 'Actualizado'] 

resultado
# Out:
#    ID            Producto Categoría                          Cliente  \
# 0   1  Torta de Chocolate    postre  Julieta Verónica Vergara Aquino
# 2   3   Gelatina de Fresa    postre     Luis Roberto Torres Gonzales
# 4   5     Arroz con Leche    postre   Maria Rafaela Torres Maldonado
#
#         DNI Fecha de Nacimiento  Precio                   Imagen         Hora  \
# 0  42514784          19-02-1984     5.5  af_Nnz0Jyn_4QhIPnb.jpeg  09:22:12 AM
# 2  46238625          23-04-1985     4.5       images_UgZuKKp.png  10:37:45 AM
# 4  72632605          02-03-1980     3.6          af_0ZtBRQD.jpeg  11:47:48 AM
#
#                  Actualizado
# 0 2019-09-16 22:22:12.314973
# 2 2019-09-16 22:37:45.498348
# 4 2019-09-16 22:47:48.986866

# %%
import matplotlib.pyplot as plot
import numpy as np

# Tamaño del gráfico 
plot.rcParams["figure.figsize"] = 20,11

# Defino los campos del gráfico 
horas = resultado['Hora']
posisicion_y = np.arange(len(horas))
productos = resultado['Producto']

# Formateo los elementos del gráfico 
plot.plot(posisicion_y, productos, alpha=0.5)
plot.xticks(posisicion_y, horas)
plot.xticks(fontsize=16)
plot.yticks(fontsize=16)

# Defino el título y las etiquetas (labels) del gráfico 
plot.title('Día: 16-09-2019', fontsize=24, pad=25)
plot.xlabel('Hora', fontsize=20, labelpad=25)
plot.ylabel('Producto', fontsize=20, labelpad=25)

# Imprimo el gráfico 
plot.scatter(posisicion_y, productos) # Añado puntos azules al gráfico
plot.show()
